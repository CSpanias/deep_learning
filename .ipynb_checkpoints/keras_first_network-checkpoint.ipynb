# %% [markdown]
# This notebook's content is based on: [Your First Deep Learning Project in Python with Keras Step-By-Step](https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/)

# %% [markdown]
# # Content
#
# 1. [Load Data](#loadData)
# 1. [Define Keras Model](#define)
# 1. [Compile Keras Model](#compile)
# 1. [Fit Keras Model](#fit)
# 1. [Evaluate Keras Model](#evaluate)
# 1. [Tie It All Together](#all)
# 1. [Make Predictions](#predict)
# 1. [Keras Tutorials Extensions](#extensions)
# 1. [Related Tutorials](#related)

# %% [markdown]
# <a name='loadData'></a>
# # 1. Load Data

# %%
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# In this Keras tutorial, we are going to use the [__Pima Indians onset of diabetes dataset__](https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.names).
#
# It is a __binary classification problem__ (onset of diabetes as 1 or not as 0). All of the input variables that describe each patient are __numerical__.
#
# The dataset is available from [here](https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv).

# %% [markdown]
# We can now load the file as a matrix of numbers using the NumPy function `loadtxt()`.
#
# There are __eight input variables__ and __one output variable__ (the last column). We will be learning a model to map rows of input variables (X) to an output variable (y), which we often summarize as `y = f(X)`.
#
# The variables can be summarized as follows:
#
# __Input Variables__ (X):
#
# 1. Number of times pregnant
# 1. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# 1. Diastolic blood pressure (mm Hg)
# 1. Triceps skin fold thickness (mm)
# 1. 2-Hour serum insulin (mu U/ml)
# 1. Body mass index (weight in kg/(height in m)^2)
# 1. Diabetes pedigree function
# 1. Age (years)
#
# __Output Variables__ (y):
#
# 1. Class variable (0 or 1)

# %%
# load dataset
dataset = loadtxt('https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv',
                 delimiter=",")

# %% [markdown]
# The data will be stored in a __2D array__ where the first dimension is rows and the second dimension is columns, e.g. `[rows, columns]`.

# %%
# check shape
print(dataset.shape)
# Out:
# (768, 9)

# %% [markdown]
# We can split the array into two arrays by selecting subsets of columns using the standard [NumPy slice operator](https://machinelearningmastery.com/index-slice-reshape-numpy-arrays-machine-learning-python/) `:`.
#
# We can select the __first 8 columns__ from index `0` to index `7` via the slice `0:8`. We can then select the __output column__ (the 9th variable) via index `8`.

# %%
# split data into X and y

# select all rows from 1st dim, and 8th from 2nd dim
X = dataset[:, 0:8]
# select all rows from 1st dim, and just the 9th from 2nd dim
y = dataset[:, 8]

print(f"X has {X.ndim} dimensions and its shape is: {X.shape}.")
print(f"y has {y.ndim} dimensions and its shape is: {y.shape}.")
# Out:
# X has 2 dimensions and its shape is: (768, 8).
# y has 1 dimensions and its shape is: (768,).

# %% [markdown]
# <a name="define"></a>
# # 2. Define Keras Model

# %% [markdown]
# Models in Keras are defined as a __sequence of layers__.
#
# We create a [__Sequential model__](https://keras.io/api/models/sequential/) and __add layers one at a time__ until we are happy with our network architecture.

# %%
# define model
model = Sequential()

# %% [markdown]
# How do we know the number of layers and their [types](https://keras.io/api/layers/core_layers/)?
#
# There are heuristics that we can use and often the best network structure is found through a process of [trial and error experimentation](https://machinelearningmastery.com/how-to-configure-the-number-of-layers-and-nodes-in-a-neural-network/). Generally, you need a network large enough to capture the structure of the problem.
#
# In this example, we will use a __fully-connected network structure with three layers__.
#
# Fully connected layers are defined using the `Dense` class. We can specify the __number of neurons or nodes in the layer as the first argument__, and specify the __activation function__ using the `activation` argument.
#
# We will use the __rectified linear unit activation function__ referred to as `relu` on the first two layers and the `sigmoid` function in the output layer.

# %% [markdown]
# The first thing to get right is to __ensure the input layer has the right number of input features__.
#
# This can be specified when creating the first layer with the `input_dim` argument and setting it to $8$ for the $8$ input variables.

# %%
# define 1st layer
model.add(Dense(units=12, input_dim=8, activation='relu'))
model.add(Dense(units=8, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %% [markdown]
# Note, the most confusing thing here is that the __shape of the input to the model is defined as an argument on the first hidden layer__.
#
# This means that the line of code that adds the first Dense layer is doing 2 things:
# 1. defining the input or visible layer
# 2. defining the first hidden layer.

# %% [markdown]
# <a name="compile"></a>
# # 3. Compile Keras Model

# %% [markdown]
# Compiling the model uses the efficient numerical libraries under the covers (the so-called __backend__) such as TensorFlow. The backend automatically chooses the best way to represent the network for training and making predictions to run on your hardware, such as CPU or GPU or even distributed.
#
# We must specify the [`loss` function](https://machinelearningmastery.com/how-to-choose-loss-functions-when-training-deep-learning-neural-networks/) to use to evaluate a set of weights, the `optimizer` is used to search through different weights for the network and any optional `metrics` we would like to collect and report during training.
#
# In this case, we will use cross entropy as the `loss` argument. This loss is for a __binary classification__ problems and is defined in Keras as `binary_crossentropy`.
#
# We will define the `optimizer` as the efficient SGD algorithm [`adam`](https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/). This is a popular version of GD because it automatically tunes itself and gives good results in a wide range of problems.
#
# Finally, because it is a classification problem, we will collect and report the classification `accuracy`, defined via the `metrics` argument.

# %%
# compile model
model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %% [markdown]
# <a name="fit"></a>
# # 4. Fit Keras Model

# %% [markdown]
# We can train our model on our loaded data by calling the `fit()` function on the model.
#
# Training occurs over [__epochs__ and each epoch is split into __batches__](https://machinelearningmastery.com/difference-between-a-batch-and-an-epoch/).
#
# * __Epoch__: One pass through all of the rows in the training dataset.
# * __Batch__: One or more samples considered by the model within an epoch before weights are updated.
#
#
# One epoch is comprised of one or more batches, based on the chosen __batch size__ and the model is fit for many epochs.
#
# The training process will run for a fixed number of iterations through the dataset called epochs, that we must specify using the `epochs` argument.
#
# We must also set the number of dataset rows that are considered before the model weights are updated within each epoch, called the batch size and set using the `batch_size` argument.
#
# For this problem, we will run for a small number of epochs (`150`) and use a relatively small batch size of `10`.
#
# These configurations can be chosen experimentally by trial and error. We want to train the model enough so that it learns a good (or good enough) mapping of rows of input data to the output classification.
#
# The model will always have some error, but the amount of error will level out after some point for a given model configuration. This is called __model convergence__.

# %%
# train model
model.fit(X, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4724 - accuracy: 0.7734
# Epoch 2/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4759 - accuracy: 0.7760
# Epoch 3/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4666 - accuracy: 0.7721
# Epoch 4/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4978 - accuracy: 0.7682
# Epoch 5/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4771 - accuracy: 0.7656
# Epoch 6/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4797 - accuracy: 0.7643
# Epoch 7/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4727 - accuracy: 0.7812
# Epoch 8/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4729 - accuracy: 0.7734
# Epoch 9/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4615 - accuracy: 0.7682
# Epoch 10/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4803 - accuracy: 0.7669
# Epoch 11/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4628 - accuracy: 0.7760
# Epoch 12/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4836 - accuracy: 0.7643
# Epoch 13/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4760 - accuracy: 0.7643
# Epoch 14/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4604 - accuracy: 0.7747
# Epoch 15/150
# 77/77 [==============================] - 0s 955us/step - loss: 0.4652 - accuracy: 0.7695
# Epoch 16/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4717 - accuracy: 0.7682
# Epoch 17/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4726 - accuracy: 0.7643
# Epoch 18/150
# 77/77 [==============================] - 0s 958us/step - loss: 0.4662 - accuracy: 0.7760
# Epoch 19/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4642 - accuracy: 0.7682
# Epoch 20/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5275 - accuracy: 0.7630
# Epoch 21/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4573 - accuracy: 0.7760
# Epoch 22/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4663 - accuracy: 0.7643
# Epoch 23/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4556 - accuracy: 0.7878
# Epoch 24/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4763 - accuracy: 0.7669
# Epoch 25/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4843 - accuracy: 0.7591
# Epoch 26/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4784 - accuracy: 0.7669
# Epoch 27/150
# 77/77 [==============================] - 0s 998us/step - loss: 0.4574 - accuracy: 0.7773
# Epoch 28/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4588 - accuracy: 0.7773
# Epoch 29/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4632 - accuracy: 0.7721
# Epoch 30/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4657 - accuracy: 0.7786
# Epoch 31/150
# 77/77 [==============================] - 0s 953us/step - loss: 0.4638 - accuracy: 0.7708
# Epoch 32/150
# 77/77 [==============================] - 0s 979us/step - loss: 0.4585 - accuracy: 0.7773
# Epoch 33/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4651 - accuracy: 0.7747
# Epoch 34/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4668 - accuracy: 0.7695
# Epoch 35/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4471 - accuracy: 0.7826
# Epoch 36/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4625 - accuracy: 0.7734
# Epoch 37/150
# 77/77 [==============================] - 0s 853us/step - loss: 0.4608 - accuracy: 0.7760
# Epoch 38/150
# 77/77 [==============================] - 0s 919us/step - loss: 0.4639 - accuracy: 0.7852
# Epoch 39/150
# 77/77 [==============================] - 0s 905us/step - loss: 0.4457 - accuracy: 0.7786
# Epoch 40/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4599 - accuracy: 0.7812
# Epoch 41/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4623 - accuracy: 0.7799
# Epoch 42/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4584 - accuracy: 0.7839
# Epoch 43/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4621 - accuracy: 0.7812
# Epoch 44/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4555 - accuracy: 0.8008
# Epoch 45/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4735 - accuracy: 0.7799
# Epoch 46/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4718 - accuracy: 0.7695
# Epoch 47/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4589 - accuracy: 0.7786
# Epoch 48/150
# 77/77 [==============================] - 0s 972us/step - loss: 0.4601 - accuracy: 0.7734
# Epoch 49/150
# 77/77 [==============================] - 0s 919us/step - loss: 0.4536 - accuracy: 0.7812
# Epoch 50/150
# 77/77 [==============================] - 0s 958us/step - loss: 0.4654 - accuracy: 0.7878
# Epoch 51/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4670 - accuracy: 0.7773
# Epoch 52/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4580 - accuracy: 0.7734
# Epoch 53/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4626 - accuracy: 0.7643
# Epoch 54/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4614 - accuracy: 0.7747
# Epoch 55/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4489 - accuracy: 0.7812
# Epoch 56/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4494 - accuracy: 0.7891
# Epoch 57/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4546 - accuracy: 0.7799
# Epoch 58/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4688 - accuracy: 0.7773
# Epoch 59/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4576 - accuracy: 0.7786
# Epoch 60/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4609 - accuracy: 0.7760
# Epoch 61/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4565 - accuracy: 0.7760
# Epoch 62/150
# 77/77 [==============================] - 0s 889us/step - loss: 0.4591 - accuracy: 0.7708
# Epoch 63/150
# 77/77 [==============================] - 0s 898us/step - loss: 0.4656 - accuracy: 0.7839
# Epoch 64/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4567 - accuracy: 0.7721
# Epoch 65/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4604 - accuracy: 0.7865
# Epoch 66/150
# 77/77 [==============================] - 0s 948us/step - loss: 0.4569 - accuracy: 0.7630
# Epoch 67/150
# 77/77 [==============================] - 0s 931us/step - loss: 0.4461 - accuracy: 0.7826
# Epoch 68/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4849 - accuracy: 0.7734
# Epoch 69/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4466 - accuracy: 0.7839
# Epoch 70/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4620 - accuracy: 0.7773
# Epoch 71/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4441 - accuracy: 0.7812
# Epoch 72/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4548 - accuracy: 0.7786
# Epoch 73/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4604 - accuracy: 0.7747
# Epoch 74/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4484 - accuracy: 0.7878
# Epoch 75/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4612 - accuracy: 0.7865
# Epoch 76/150
# 77/77 [==============================] - 0s 900us/step - loss: 0.4517 - accuracy: 0.7812
# Epoch 77/150
# 77/77 [==============================] - 0s 928us/step - loss: 0.4508 - accuracy: 0.7721
# Epoch 78/150
# 77/77 [==============================] - 0s 957us/step - loss: 0.4525 - accuracy: 0.7852
# Epoch 79/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4537 - accuracy: 0.7839
# Epoch 80/150
# 77/77 [==============================] - 0s 979us/step - loss: 0.4538 - accuracy: 0.7812
# Epoch 81/150
# 77/77 [==============================] - 0s 967us/step - loss: 0.4485 - accuracy: 0.7826
# Epoch 82/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4450 - accuracy: 0.7747
# Epoch 83/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4548 - accuracy: 0.7891
# Epoch 84/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4880 - accuracy: 0.7630
# Epoch 85/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4512 - accuracy: 0.7721
# Epoch 86/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4456 - accuracy: 0.7812
# Epoch 87/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4574 - accuracy: 0.7878
# Epoch 88/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4424 - accuracy: 0.7891
# Epoch 89/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4545 - accuracy: 0.7786
# Epoch 90/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4573 - accuracy: 0.7930
# Epoch 91/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4486 - accuracy: 0.7917
# Epoch 92/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4468 - accuracy: 0.7826
# Epoch 93/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4581 - accuracy: 0.7799
# Epoch 94/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4522 - accuracy: 0.7839
# Epoch 95/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4450 - accuracy: 0.7904
# Epoch 96/150
# 77/77 [==============================] - 0s 968us/step - loss: 0.4536 - accuracy: 0.7852
# Epoch 97/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4341 - accuracy: 0.7943
# Epoch 98/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4440 - accuracy: 0.7786
# Epoch 99/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4443 - accuracy: 0.7826
# Epoch 100/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4451 - accuracy: 0.7721
# Epoch 101/150
# 77/77 [==============================] - 0s 947us/step - loss: 0.4373 - accuracy: 0.7917
# Epoch 102/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4452 - accuracy: 0.8008
# Epoch 103/150
# 77/77 [==============================] - 0s 931us/step - loss: 0.4618 - accuracy: 0.7878
# Epoch 104/150
# 77/77 [==============================] - 0s 879us/step - loss: 0.4362 - accuracy: 0.7773
# Epoch 105/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4575 - accuracy: 0.7852
# Epoch 106/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4441 - accuracy: 0.7812
# Epoch 107/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4412 - accuracy: 0.7878
# Epoch 108/150
# 77/77 [==============================] - 0s 971us/step - loss: 0.4473 - accuracy: 0.7695
# Epoch 109/150
# 77/77 [==============================] - 0s 919us/step - loss: 0.4325 - accuracy: 0.7865
# Epoch 110/150
# 77/77 [==============================] - 0s 886us/step - loss: 0.4459 - accuracy: 0.7917
# Epoch 111/150
# 77/77 [==============================] - 0s 899us/step - loss: 0.4414 - accuracy: 0.7852
# Epoch 112/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4506 - accuracy: 0.7799
# Epoch 113/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4332 - accuracy: 0.7995
# Epoch 114/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4484 - accuracy: 0.7786
# Epoch 115/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4593 - accuracy: 0.7747
# Epoch 116/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4400 - accuracy: 0.7812
# Epoch 117/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4456 - accuracy: 0.7721
# Epoch 118/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4338 - accuracy: 0.7930
# Epoch 119/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4409 - accuracy: 0.7826
# Epoch 120/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4517 - accuracy: 0.7799
# Epoch 121/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4371 - accuracy: 0.7865
# Epoch 122/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4443 - accuracy: 0.7799
# Epoch 123/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4372 - accuracy: 0.7969
# Epoch 124/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4443 - accuracy: 0.7917
# Epoch 125/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4647 - accuracy: 0.7682
# Epoch 126/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4448 - accuracy: 0.7904
# Epoch 127/150
# 77/77 [==============================] - 0s 969us/step - loss: 0.4462 - accuracy: 0.7904
# Epoch 128/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5036 - accuracy: 0.7617
# Epoch 129/150
# 77/77 [==============================] - 0s 988us/step - loss: 0.4408 - accuracy: 0.7826
# Epoch 130/150
# 77/77 [==============================] - 0s 958us/step - loss: 0.4445 - accuracy: 0.7865
# Epoch 131/150
# 77/77 [==============================] - 0s 995us/step - loss: 0.4368 - accuracy: 0.7969
# Epoch 132/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4401 - accuracy: 0.7969
# Epoch 133/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4455 - accuracy: 0.7734
# Epoch 134/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4374 - accuracy: 0.7917
# Epoch 135/150
# 77/77 [==============================] - 0s 997us/step - loss: 0.4414 - accuracy: 0.7956
# Epoch 136/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4324 - accuracy: 0.7995
# Epoch 137/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4554 - accuracy: 0.7904
# Epoch 138/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4326 - accuracy: 0.7995
# Epoch 139/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4320 - accuracy: 0.7904
# Epoch 140/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4309 - accuracy: 0.7995
# Epoch 141/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4332 - accuracy: 0.7969
# Epoch 142/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4377 - accuracy: 0.7917
# Epoch 143/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4490 - accuracy: 0.7865
# Epoch 144/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4349 - accuracy: 0.7904
# Epoch 145/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4442 - accuracy: 0.7891
# Epoch 146/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4509 - accuracy: 0.7969
# Epoch 147/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4621 - accuracy: 0.7773
# Epoch 148/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4358 - accuracy: 0.7865
# Epoch 149/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4375 - accuracy: 0.7891
# Epoch 150/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4448 - accuracy: 0.7904

# %% [markdown]
# <a name="evaluate"></a>
# # 5. Evaluate Keras Model

# %% [markdown]
# We have trained our neural network on the entire dataset and we can evaluate the performance of the network on the same dataset.
#
# This will only give us an idea of how well we have modeled the dataset (e.g. __train accuracy__), but no idea of how well the algorithm might perform on new data. We have done this for simplicity, but ideally, you could separate your data into train and test datasets for training and evaluation of your model.
#
# You can evaluate your model on your training dataset using the `evaluate()` function on your model and pass it the same input and output used to train the model.
#
# This will generate a prediction for each input and output pair and collect scores, including the average loss and any metrics you have configured, such as `accuracy`.
#
# The `evaluate()` function will return a list with two values.
# 1. the `loss` of the model on the dataset
# 2. the `accuracy` of the model on the dataset.
#
# We are only interested in reporting the accuracy, so we will ignore the loss value.

# %%
# evaluate model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4174 - accuracy: 0.7982
# Accuracy: 79.82

# %% [markdown]
# <a name="all"></a>
# # 6. Tie It All Together

# %%
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

# load the dataset
dataset = loadtxt('https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv',
                  delimiter=',')

# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# compile the keras model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10)

# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 1ms/step - loss: 1.6061 - accuracy: 0.6042
# Epoch 2/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.0560 - accuracy: 0.6094
# Epoch 3/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.9021 - accuracy: 0.6029
# Epoch 4/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.8304 - accuracy: 0.5872
# Epoch 5/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7647 - accuracy: 0.6250
# Epoch 6/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7363 - accuracy: 0.6185
# Epoch 7/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7073 - accuracy: 0.6172
# Epoch 8/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6964 - accuracy: 0.6172
# Epoch 9/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7000 - accuracy: 0.6172
# Epoch 10/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6614 - accuracy: 0.6510
# Epoch 11/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6826 - accuracy: 0.6471
# Epoch 12/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6602 - accuracy: 0.6589
# Epoch 13/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6692 - accuracy: 0.6602
# Epoch 14/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6403 - accuracy: 0.6745
# Epoch 15/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6205 - accuracy: 0.6602
# Epoch 16/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6600 - accuracy: 0.6719
# Epoch 17/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6085 - accuracy: 0.6654
# Epoch 18/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6152 - accuracy: 0.6745
# Epoch 19/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6371 - accuracy: 0.6667
# Epoch 20/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6069 - accuracy: 0.6888
# Epoch 21/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6333 - accuracy: 0.6602
# Epoch 22/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6011 - accuracy: 0.6914
# Epoch 23/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5979 - accuracy: 0.7005
# Epoch 24/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5997 - accuracy: 0.6940
# Epoch 25/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6049 - accuracy: 0.6823
# Epoch 26/150
# 77/77 [==============================] - 0s 962us/step - loss: 0.5704 - accuracy: 0.7240
# Epoch 27/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5984 - accuracy: 0.6914
# Epoch 28/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6186 - accuracy: 0.6849
# Epoch 29/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5811 - accuracy: 0.7057
# Epoch 30/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5769 - accuracy: 0.7083
# Epoch 31/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5681 - accuracy: 0.7135
# Epoch 32/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5770 - accuracy: 0.7044
# Epoch 33/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5963 - accuracy: 0.7031
# Epoch 34/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6003 - accuracy: 0.7070
# Epoch 35/150
# 77/77 [==============================] - 0s 971us/step - loss: 0.5705 - accuracy: 0.7135
# Epoch 36/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5608 - accuracy: 0.7240
# Epoch 37/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5828 - accuracy: 0.7161
# Epoch 38/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5646 - accuracy: 0.7109
# Epoch 39/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5709 - accuracy: 0.7161
# Epoch 40/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5864 - accuracy: 0.7135
# Epoch 41/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5580 - accuracy: 0.7188
# Epoch 42/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5628 - accuracy: 0.7122
# Epoch 43/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5623 - accuracy: 0.6966
# Epoch 44/150
# 77/77 [==============================] - 0s 919us/step - loss: 0.5533 - accuracy: 0.7253
# Epoch 45/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5390 - accuracy: 0.7344
# Epoch 46/150
# 77/77 [==============================] - 0s 972us/step - loss: 0.5432 - accuracy: 0.7357
# Epoch 47/150
# 77/77 [==============================] - 0s 970us/step - loss: 0.5752 - accuracy: 0.7096
# Epoch 48/150
# 77/77 [==============================] - 0s 964us/step - loss: 0.5623 - accuracy: 0.7357
# Epoch 49/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5833 - accuracy: 0.7188
# Epoch 50/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5506 - accuracy: 0.7253
# Epoch 51/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7253
# Epoch 52/150
# 77/77 [==============================] - 0s 971us/step - loss: 0.5405 - accuracy: 0.7318
# Epoch 53/150
# 77/77 [==============================] - 0s 999us/step - loss: 0.5335 - accuracy: 0.7409
# Epoch 54/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5218 - accuracy: 0.7370
# Epoch 55/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5639 - accuracy: 0.7174
# Epoch 56/150
# 77/77 [==============================] - 0s 964us/step - loss: 0.5375 - accuracy: 0.7266
# Epoch 57/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5475 - accuracy: 0.7279
# Epoch 58/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5298 - accuracy: 0.7422
# Epoch 59/150
# 77/77 [==============================] - 0s 932us/step - loss: 0.5349 - accuracy: 0.7370
# Epoch 60/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5418 - accuracy: 0.7305
# Epoch 61/150
# 77/77 [==============================] - 0s 961us/step - loss: 0.5310 - accuracy: 0.7318
# Epoch 62/150
# 77/77 [==============================] - 0s 984us/step - loss: 0.5301 - accuracy: 0.7474
# Epoch 63/150
# 77/77 [==============================] - 0s 976us/step - loss: 0.5247 - accuracy: 0.7513
# Epoch 64/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5187 - accuracy: 0.7305
# Epoch 65/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5134 - accuracy: 0.7396
# Epoch 66/150
# 77/77 [==============================] - 0s 966us/step - loss: 0.5376 - accuracy: 0.7357
# Epoch 67/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5341 - accuracy: 0.7435
# Epoch 68/150
# 77/77 [==============================] - 0s 984us/step - loss: 0.5391 - accuracy: 0.7409
# Epoch 69/150
# 77/77 [==============================] - 0s 984us/step - loss: 0.5169 - accuracy: 0.7435
# Epoch 70/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5288 - accuracy: 0.7396
# Epoch 71/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5138 - accuracy: 0.7513
# Epoch 72/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5492 - accuracy: 0.7240
# Epoch 73/150
# 77/77 [==============================] - 0s 840us/step - loss: 0.5157 - accuracy: 0.7357
# Epoch 74/150
# 77/77 [==============================] - 0s 944us/step - loss: 0.5389 - accuracy: 0.7578
# Epoch 75/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5154 - accuracy: 0.7448
# Epoch 76/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5392 - accuracy: 0.7396
# Epoch 77/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5410 - accuracy: 0.7266
# Epoch 78/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5164 - accuracy: 0.7604
# Epoch 79/150
# 77/77 [==============================] - 0s 977us/step - loss: 0.5048 - accuracy: 0.7578
# Epoch 80/150
# 77/77 [==============================] - 0s 943us/step - loss: 0.5223 - accuracy: 0.7461
# Epoch 81/150
# 77/77 [==============================] - 0s 995us/step - loss: 0.5204 - accuracy: 0.7279
# Epoch 82/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5074 - accuracy: 0.7578
# Epoch 83/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5145 - accuracy: 0.7513
# Epoch 84/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5167 - accuracy: 0.7565
# Epoch 85/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5166 - accuracy: 0.7591
# Epoch 86/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5017 - accuracy: 0.7565
# Epoch 87/150
# 77/77 [==============================] - 0s 984us/step - loss: 0.5194 - accuracy: 0.7435
# Epoch 88/150
# 77/77 [==============================] - 0s 991us/step - loss: 0.5295 - accuracy: 0.7279
# Epoch 89/150
# 77/77 [==============================] - 0s 940us/step - loss: 0.5144 - accuracy: 0.7448
# Epoch 90/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5243 - accuracy: 0.7487
# Epoch 91/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5043 - accuracy: 0.7474
# Epoch 92/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5244 - accuracy: 0.7643
# Epoch 93/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5081 - accuracy: 0.7552
# Epoch 94/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5033 - accuracy: 0.7552
# Epoch 95/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5088 - accuracy: 0.7526
# Epoch 96/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4997 - accuracy: 0.7552
# Epoch 97/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5030 - accuracy: 0.7630
# Epoch 98/150
# 77/77 [==============================] - 0s 926us/step - loss: 0.5049 - accuracy: 0.7344
# Epoch 99/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5214 - accuracy: 0.7474
# Epoch 100/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5052 - accuracy: 0.7734
# Epoch 101/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5033 - accuracy: 0.7630
# Epoch 102/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4976 - accuracy: 0.7591
# Epoch 103/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5028 - accuracy: 0.7591
# Epoch 104/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4981 - accuracy: 0.7539
# Epoch 105/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4969 - accuracy: 0.7409
# Epoch 106/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4912 - accuracy: 0.7617
# Epoch 107/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4991 - accuracy: 0.7565
# Epoch 108/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5272 - accuracy: 0.7383
# Epoch 109/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5040 - accuracy: 0.7565
# Epoch 110/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4992 - accuracy: 0.7500
# Epoch 111/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4979 - accuracy: 0.7591
# Epoch 112/150
# 77/77 [==============================] - 0s 905us/step - loss: 0.4949 - accuracy: 0.7500
# Epoch 113/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5137 - accuracy: 0.7422
# Epoch 114/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5054 - accuracy: 0.7630
# Epoch 115/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4829 - accuracy: 0.7773
# Epoch 116/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4887 - accuracy: 0.7656
# Epoch 117/150
# 77/77 [==============================] - 0s 919us/step - loss: 0.4985 - accuracy: 0.7435
# Epoch 118/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4877 - accuracy: 0.7695
# Epoch 119/150
# 77/77 [==============================] - 0s 971us/step - loss: 0.4877 - accuracy: 0.7474
# Epoch 120/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4858 - accuracy: 0.7643
# Epoch 121/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4778 - accuracy: 0.7786
# Epoch 122/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5149 - accuracy: 0.7526
# Epoch 123/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5072 - accuracy: 0.7487
# Epoch 124/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4909 - accuracy: 0.7513
# Epoch 125/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4912 - accuracy: 0.7487
# Epoch 126/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4879 - accuracy: 0.7552
# Epoch 127/150
# 77/77 [==============================] - 0s 997us/step - loss: 0.5177 - accuracy: 0.7435
# Epoch 128/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4994 - accuracy: 0.7487
# Epoch 129/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5179 - accuracy: 0.7526
# Epoch 130/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4864 - accuracy: 0.7630
# Epoch 131/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5048 - accuracy: 0.7461
# Epoch 132/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4950 - accuracy: 0.7630
# Epoch 133/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5090 - accuracy: 0.7474
# Epoch 134/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4770 - accuracy: 0.7734
# Epoch 135/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4768 - accuracy: 0.7656
# Epoch 136/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4718 - accuracy: 0.7695
# Epoch 137/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4635 - accuracy: 0.7799
# Epoch 138/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4792 - accuracy: 0.7643
# Epoch 139/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4827 - accuracy: 0.7695
# Epoch 140/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4741 - accuracy: 0.7721
# Epoch 141/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4791 - accuracy: 0.7695
# Epoch 142/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4798 - accuracy: 0.7682
# Epoch 143/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4700 - accuracy: 0.7878
# Epoch 144/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4747 - accuracy: 0.7643
# Epoch 145/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4778 - accuracy: 0.7656
# Epoch 146/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4848 - accuracy: 0.7422
# Epoch 147/150
# 77/77 [==============================] - 0s 998us/step - loss: 0.4714 - accuracy: 0.7630
# Epoch 148/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4628 - accuracy: 0.7721
# Epoch 149/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5014 - accuracy: 0.7487
# Epoch 150/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4688 - accuracy: 0.7591
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4596 - accuracy: 0.7786
# Accuracy: 77.86

# %% [markdown]
# <a name='predict'></a>
# # 7. Make Predictions

# %% [markdown]
# We can adapt the above example and use it to generate predictions on the training dataset, pretending it is a new dataset we have not seen before.
#
# [Making predictions](https://machinelearningmastery.com/how-to-make-classification-and-regression-predictions-for-deep-learning-models-in-keras/) is as easy as calling the `predict()` function on the model. We are using a `sigmoid` activation function on the output layer, so the predictions will be a __probability in the range between `0` and `1`__.
#
# We can easily convert them into a crisp binary prediction for this classification task by rounding them.

# %%
# make prob preds
predictions = model.predict(X)
# round preds
rounded = [round(x[0]) for x in predictions]

# or make class preds directly
# predictions = (model.predict(X) > 0.5).astype(int)
# summarize the first 5 cases
for i in range(5):
	print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 0 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 0 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] => 0 (expected 1)

# %% [markdown]
# <a name='extensions'></a>
# # 8. Keras Tutorial Extensions

# %% [markdown]
# 1. __Tune the Model__: Change the configuration of the model or training process and see if you can improve the performance of the model, e.g. achieve better than 76% accuracy.
# 1. [__Save the Model__](https://machinelearningmastery.com/save-load-keras-deep-learning-models/): Update the tutorial to save the model to file, then load it later and use it to make predictions.
# 1. [__Summarize the Model__](https://machinelearningmastery.com/visualize-deep-learning-neural-network-model-keras/): Update the tutorial to summarize the model and create a plot of model layers.
# 1. __Separate Train and Test Datasets__. Split the loaded dataset into a train and test set (split based on rows) and use one set to train the model and the other set to estimate the performance of the model on new data.
# 1. [__Plot Learning Curves__](https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/): The `fit()` function returns a history object that summarizes the `loss` and `accuracy` at the end of each epoch. Create line plots of this data, called [learning curves](https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/).
# 1. [__Learn a New Dataset__](https://archive.ics.uci.edu/ml/index.php): Update the tutorial to use a different tabular dataset, perhaps from the UCI Machine Learning Repository.
# 1. [__Use Functional API__](https://machinelearningmastery.com/keras-functional-api-deep-learning/): Update the tutorial to use the Keras Functional API for defining the model (see this tutorial).

# %% [markdown]
# <a name="related"></a>
# # 9. Related Tutorials

# %% [markdown]
# 1. [5 Step Life-Cycle for Neural Network Models in Keras](https://machinelearningmastery.com/5-step-life-cycle-neural-network-models-keras/)
# 1. [Multi-Class Classification Tutorial with the Keras Deep Learning Library](https://machinelearningmastery.com/multi-class-classification-tutorial-keras-deep-learning-library/)
# 1. [Regression Tutorial with the Keras Deep Learning Library in Python](https://machinelearningmastery.com/regression-tutorial-keras-deep-learning-library-python/)
# 1. [How to Grid Search Hyperparameters for Deep Learning Models in Python With Keras](https://machinelearningmastery.com/grid-search-hyperparameters-deep-learning-models-python-keras/)
